# %%
from SMABacktester import SMABacktester as SMA

# %%
# Choose ticker and moving averages to backtest
strategy = SMA('META',12,154, '2024-1-1')

# Run strategy
strategy.run_strategy()

# visualize
# 'returns' will show the returns comparison between buy/hold and sma
# 'sma' will show the golden/death crosses of the sma's and where trades would be initiated.
strategy.visual('returns')
strategy.visual('sma')


# Optimize averages
# input is sma1, sma2 as: (minimum avg, maximum avg, step size)
strategy.optimize((2,70,2), (100,400,2))
# Out:
# /Users/antonyponomarev/Desktop/quant/SMA-Backtest/SMABacktester.py:31: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(self.symbol, self.start)
# [*********************100%***********************]  1 of 1 completed
# Annualized buy and hold Sharpe:  1.1237656424478015
# Annualized strategy Sharpe:  1.40818008228483
# (array([ 12., 154.]), np.float64(1.65))
